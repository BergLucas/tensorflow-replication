# %% [markdown]
# # Minimized

# %%
from tensorflow.python.eager.tape import Tape

tape = Tape("")
tape.watched_variables()

# %% [markdown]
# # Raw

# %%
import tensorflow.python.eager.tape as module_0

str_0 = "*/"
tape_0 = module_0.Tape(str_0)
tape_0.watched_variables()
