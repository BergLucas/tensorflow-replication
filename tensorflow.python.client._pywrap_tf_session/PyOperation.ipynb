# %% [markdown]
# # Minimized

# %%
from tensorflow.python.client.pywrap_tf_session import PyOperation

PyOperation(None, None)

# %% [markdown]
# # Raw

# %%
import tensorflow.python.client._pywrap_tf_session as module_0

none_type_0 = None
list_0 = [none_type_0, none_type_0]
module_0.PyOperation(*list_0)
