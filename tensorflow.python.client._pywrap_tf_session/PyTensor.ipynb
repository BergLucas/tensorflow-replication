# %% [markdown]
# # Minimized

# %%
from tensorflow.python.client.pywrap_tf_session import PyTensor

PyTensor("", "", "", "")

# %% [markdown]
# # Raw

# %%
import numpy as module_0
import tensorflow.python.client._pywrap_tf_session as module_1

var_0 = module_0.geterr()
module_1.PyTensor(*var_0, **var_0)
